# %% [markdown]
# # Graph RAG: Graph-Enhanced Retrieval-Augmented Generation
#
# In this notebook, I implement Graph RAG - a technique that enhances traditional RAG systems by organizing knowledge as a connected graph rather than a flat collection of documents. This allows the system to navigate related concepts and retrieve more contextually relevant information than standard vector similarity approaches.
#
# Key Benefits of Graph RAG
#
# - Preserves relationships between pieces of information
# - Enables traversal through connected concepts to find relevant context
# - Improves handling of complex, multi-part queries
# - Provides better explainability through visualized knowledge paths

# %% [markdown]
# ## Setting Up the Environment
# We begin by importing necessary libraries.

# %%
# !pip install -qU pymupdf
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 71.9 MB/s eta 0:00:00

# %%
import os
import numpy as np
import json
import fitz  # PyMuPDF
from typing import List, Dict, Tuple, Any
import networkx as nx
import matplotlib.pyplot as plt
import heapq
from collections import defaultdict
import re
from PIL import Image
import io

import torch
import torch.nn.functional as F
from transformers import AutoTokenizer, AutoModel, AutoModelForCausalLM
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Setting Up Models

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
gen_model = AutoModelForCausalLM.from_pretrained(
    "unsloth/Llama-3.2-3B-Instruct",
    torch_dtype = "auto",
    device_map = "auto"
)
gen_tokenizer = AutoTokenizer.from_pretrained("unsloth/Llama-3.2-3B-Instruct")

embed_model = AutoModel.from_pretrained("BAAI/bge-base-en-v1.5").to(device)
embed_tokenizer = AutoTokenizer.from_pretrained("BAAI/bge-base-en-v1.5")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/890 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/777 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %% [markdown]
# ## Document Processing Functions

# %%
def extract_text_from_pdf(pdf_path):
    """
    Extract text content from a PDF file.

    Args:
        pdf_path (str): Path to the PDF file

    Returns:
        str: Extracted text content
    """
    print(f"Extracting text from {pdf_path}...")  # Print the path of the PDF being processed
    pdf = fitz.open(pdf_path)
    text = ""

    for page in pdf:
      text += page.get_text()

    return text  # Return the extracted text content

# %%
text = extract_text_from_pdf("AI_Information.pdf")
# Out:
# Extracting text from AI_Information.pdf...

# %%
def chunk_text(text, chunk_size=1000, overlap=200):
    """
    Split text into overlapping chunks.

    Args:
        text (str): Input text to chunk
        chunk_size (int): Size of each chunk in characters
        overlap (int): Overlap between chunks in characters

    Returns:
        List[Dict]: List of chunks with metadata
    """
    chunks = []  # Initialize an empty list to store the chunks

    # Iterate over the text with a step size of (chunk_size - overlap)
    for i in range(0, len(text), chunk_size - overlap):
        # Extract a chunk of text from the current position
        chunk_text = text[i:i + chunk_size]

        # Ensure we don't add empty chunks
        if chunk_text:
            # Append the chunk with its metadata to the list
            chunks.append({
                "text": chunk_text,  # The chunk of text
                "index": len(chunks),  # The index of the chunk
                "start_pos": i,  # The starting position of the chunk in the original text
                "end_pos": i + len(chunk_text)  # The ending position of the chunk in the original text
            })

    # Print the number of chunks created
    print(f"Created {len(chunks)} text chunks")

    return chunks  # Return the list of chunks

# %%
chunks = chunk_text(text)
# Out:
# Created 42 text chunks

# %% [markdown]
# ## Creating Embeddings

# %%
def create_embeddings(text):
  is_single = isinstance(text, str)
  if is_single: text = [text]

  try:
    inputs = embed_tokenizer(
        text,
        padding = True,
        return_tensors = "pt"
    ).to(device)
  except Exception as e:
    print(e)
    return None

  try:
    with torch.no_grad():
      outputs = embed_model(**inputs)
      cls = outputs.last_hidden_state[:, 0, :]
      embed_normalized = F.normalize(cls, p = 2, dim = 1)
    embeddings = [embed.cpu().numpy() for embed in embed_normalized]

    return embeddings
  except Exception as e:
    print(e)
    return None

# %%
def gen(system_prompt, user_prompt, temperature=0):
    text = gen_tokenizer.apply_chat_template(
        conversation=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        tokenize=False,
        add_generation_prompt=True
    )

    model_inputs = gen_tokenizer([text], return_tensors="pt").to(device)

    if temperature > 0:
        generated_ids = gen_model.generate(
            **model_inputs,
            do_sample=True,
            temperature=temperature,
            max_new_tokens=1024
        )
    else:
        generated_ids = gen_model.generate(
            **model_inputs,
            do_sample=False,
            temperature= None,
            top_p=None,  # disable top_p and temperature to not receive warning
            max_new_tokens=1024
        )
    generated_ids = [
        output_ids[len(input_ids):]
        for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
    ]
    response = gen_tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
    return response

# %% [markdown]
# ## Knowledge Graph Construction

# %%
def extract_concepts(text):
    """
    Extract key concepts from text using OpenAI's API.

    Args:
        text (str): Text to extract concepts from

    Returns:
        List[str]: List of concepts
    """
    # System message to instruct the model on what to do
    system_message = """Extract key concepts and entities from the provided text.
Return ONLY a list of 5 key terms, entities, or concepts that are most important/relevant in this text.
Format your response as a numbered list of key concepts/terms/entities ONLY, with no additional text."""
    user_prompt = f"Extract key concepts from:\n\n{text}"
    # Make a request to the OpenAI API
    response = gen(system_message, user_prompt)
    items = []

    for line in response.split('\n'):
        items.append(re.sub(r'^\d+\.\s*', '', line.strip()))
    return items

# %%
test = extract_concepts(chunks[0])
test
# Out:
# ['Artificial Intelligence',
#  'Computing',
#  'Intelligence',
#  'Computing Power',
#  'Data']

# %%
def build_knowledge_graph(chunks):
    """
    Build a knowledge graph from text chunks.

    Args:
        chunks (List[Dict]): List of text chunks with metadata

    Returns:
        Tuple[nx.Graph, List[np.ndarray]]: The knowledge graph and chunk embeddings
    """
    print("Building knowledge graph...")

    # Create a graph
    graph = nx.Graph()

    # Extract chunk texts
    texts = [chunk["text"] for chunk in chunks]

    # Create embeddings for all chunks
    print("Creating embeddings for chunks...")
    embeddings = create_embeddings(texts)

    # Add nodes to the graph
    print("Adding nodes to the graph...")
    for i, chunk in enumerate(chunks):
        # Extract concepts from the chunk
        print(f"Extracting concepts for chunk {i+1}/{len(chunks)}...")
        concepts = extract_concepts(chunk["text"])

        # Add node with attributes
        graph.add_node(i,
                      text=chunk["text"],
                      concepts=concepts,
                      embedding=embeddings[i])

    # Connect nodes based on shared concepts
    print("Creating edges between nodes...")
    for i in range(len(chunks)):
        node_concepts = set(graph.nodes[i]["concepts"])
        print(node_concepts)
        for j in range(i + 1, len(chunks)):
            # Calculate concept overlap
            other_concepts = set(graph.nodes[j]["concepts"])
            shared_concepts = node_concepts.intersection(other_concepts)
            print(f"===intersec between {i + 1} and {j + 1}===")
            print(shared_concepts)
            # If they share concepts, add an edge
            if shared_concepts:
                # Calculate semantic similarity using embeddings
                similarity = cosine_similarity(embeddings[i].reshape(1, -1), embeddings[j].reshape(1, -1))[0][0]

                # Calculate edge weight based on concept overlap and semantic similarity
                concept_score = len(shared_concepts) / min(len(node_concepts), len(other_concepts))
                edge_weight = 0.7 * similarity + 0.3 * concept_score

                # Only add edges with significant relationship
                if edge_weight > 0.6:
                    graph.add_edge(i, j,
                                  weight=edge_weight,
                                  similarity=similarity,
                                  shared_concepts=list(shared_concepts))

    print(f"Knowledge graph built with {graph.number_of_nodes()} nodes and {graph.number_of_edges()} edges")
    return graph, embeddings

# %%
build_knowledge_graph(chunks[:10])

# %% [markdown]
# ## Graph Traversal and Query Processing

# %%
def traverse_graph(query, graph, embeddings, top_k=5, max_depth=3):
    """
    Traverse the knowledge graph to find relevant information for the query.

    Args:
        query (str): The user's question
        graph (nx.Graph): The knowledge graph
        embeddings (List): List of node embeddings
        top_k (int): Number of initial nodes to consider
        max_depth (int): Maximum traversal depth

    Returns:
        List[Dict]: Relevant information from graph traversal
    """
    print(f"Traversing graph for query: {query}")

    # Get query embedding
    query_embedding = create_embeddings(query)[0]

    # Calculate similarity between query and all nodes
    similarities = []
    for i, node_embedding in enumerate(embeddings):
        similarity = cosine_similarity(query_embedding.reshape(1, -1), node_embedding.reshape(1, -1))
        similarities.append((i, similarity))

    # Sort by similarity (descending)
    similarities.sort(key=lambda x: x[1], reverse=True)

    # Get top-k most similar nodes as starting points
    starting_nodes = [node for node, _ in similarities[:top_k]]
    print(f"Starting traversal from {len(starting_nodes)} nodes")

    # Initialize traversal
    visited = set()  # Set to keep track of visited nodes
    traversal_path = []  # List to store the traversal path
    results = []  # List to store the results

    # Use a priority queue for traversal
    queue = []
    for node in starting_nodes:
        heapq.heappush(queue, (-similarities[node][1], node))  # Negative for max-heap

    # Traverse the graph using a modified breadth-first search with priority
    while queue and len(results) < (top_k * 3):  # Limit results to top_k * 3
        _, node = heapq.heappop(queue)

        if node in visited:
            continue

        # Mark as visited
        visited.add(node)
        traversal_path.append(node)

        # Add current node's text to results
        results.append({
            "text": graph.nodes[node]["text"],
            "concepts": graph.nodes[node]["concepts"],
            "node_id": node
        })

        # Explore neighbors if we haven't reached max depth
        if len(traversal_path) < max_depth:
            neighbors = [(neighbor, graph[node][neighbor]["weight"])
                        for neighbor in graph.neighbors(node)
                        if neighbor not in visited]

            # Add neighbors to queue based on edge weight
            for neighbor, weight in sorted(neighbors, key=lambda x: x[1], reverse=True):
                heapq.heappush(queue, (-weight, neighbor))

    print(f"Graph traversal found {len(results)} relevant chunks")
    return results, traversal_path

# %% [markdown]
# ## Response Generation

# %%
def generate_response(query, context_chunks):
    """
    Generate a response using the retrieved context.

    Args:
        query (str): The user's question
        context_chunks (List[Dict]): Relevant chunks from graph traversal

    Returns:
        str: Generated response
    """
    # Extract text from each chunk in the context
    context_texts = [chunk["text"] for chunk in context_chunks]

    # Combine the extracted texts into a single context string, separated by "---"
    combined_context = "\n\n---\n\n".join(context_texts)

    # Define the maximum allowed length for the context (OpenAI limit)
    max_context = 14000

    # Truncate the combined context if it exceeds the maximum length
    if len(combined_context) > max_context:
        combined_context = combined_context[:max_context] + "... [truncated]"

    # Define the system message to guide the AI assistant
    system_message = """You are a helpful AI assistant. Answer the user's question based on the provided context.
If the information is not in the context, say so. Refer to specific parts of the context in your answer when possible."""
    user_prompt = f"Context:\n{combined_context}\n\nQuestion: {query}"
    # Generate the response using the OpenAI API
    response = gen(system_message, user_prompt, 0.2)

    # Return the generated response content
    return response

# %% [markdown]
# ## Visualization

# %%
def visualize_graph_traversal(graph, traversal_path):
    """
    Visualize the knowledge graph and the traversal path.

    Args:
        graph (nx.Graph): The knowledge graph
        traversal_path (List): List of nodes in traversal order
    """
    plt.figure(figsize=(12, 10))  # Set the figure size

    # Define node colors, default to light blue
    node_color = ['lightblue'] * graph.number_of_nodes()

    # Highlight traversal path nodes in light green
    for node in traversal_path:
        node_color[node] = 'lightgreen'

    # Highlight start node in green and end node in red
    if traversal_path:
        node_color[traversal_path[0]] = 'green'
        node_color[traversal_path[-1]] = 'red'

    # Create positions for all nodes using spring layout
    pos = nx.spring_layout(graph, k=0.5, iterations=50, seed=42)

    # Draw the graph nodes
    nx.draw_networkx_nodes(graph, pos, node_color=node_color, node_size=500, alpha=0.8)

    # Draw edges with width proportional to weight
    for u, v, data in graph.edges(data=True):
        weight = data.get('weight', 1.0)
        nx.draw_networkx_edges(graph, pos, edgelist=[(u, v)], width=weight*2, alpha=0.6)

    # Draw traversal path with red dashed lines
    traversal_edges = [(traversal_path[i], traversal_path[i+1])
                      for i in range(len(traversal_path)-1)]

    nx.draw_networkx_edges(graph, pos, edgelist=traversal_edges,
                          width=3, alpha=0.8, edge_color='red',
                          style='dashed', arrows=True)

    # Add labels with the first concept for each node
    labels = {}
    for node in graph.nodes():
        concepts = graph.nodes[node]['concepts']
        label = concepts[0] if concepts else f"Node {node}"
        labels[node] = f"{node}: {label}"

    nx.draw_networkx_labels(graph, pos, labels=labels, font_size=8)

    plt.title("Knowledge Graph with Traversal Path")  # Set the plot title
    plt.axis('off')  # Turn off the axis
    plt.tight_layout()  # Adjust layout
    plt.show()  # Display the plot

# %% [markdown]
# ## Complete Graph RAG Pipeline

# %%
def graph_rag_pipeline(pdf_path, query, chunk_size=1000, chunk_overlap=200, top_k=3):
    """
    Complete Graph RAG pipeline from document to answer.

    Args:
        pdf_path (str): Path to the PDF document
        query (str): The user's question
        chunk_size (int): Size of text chunks
        chunk_overlap (int): Overlap between chunks
        top_k (int): Number of top nodes to consider for traversal

    Returns:
        Dict: Results including answer and graph visualization data
    """
    # Extract text from the PDF document
    text = extract_text_from_pdf(pdf_path)

    # Split the extracted text into overlapping chunks
    chunks = chunk_text(text, chunk_size, chunk_overlap)

    # Build a knowledge graph from the text chunks
    graph, embeddings = build_knowledge_graph(chunks)

    # Traverse the knowledge graph to find relevant information for the query
    relevant_chunks, traversal_path = traverse_graph(query, graph, embeddings, top_k)

    # Generate a response based on the query and the relevant chunks
    response = generate_response(query, relevant_chunks)

    # Visualize the graph traversal path
    visualize_graph_traversal(graph, traversal_path)

    # Return the query, response, relevant chunks, traversal path, and the graph
    return {
        "query": query,
        "response": response,
        "relevant_chunks": relevant_chunks,
        "traversal_path": traversal_path,
        "graph": graph
    }

# %% [markdown]
# ## Evaluation Function

# %%
def evaluate_graph_rag(pdf_path, test_queries, reference_answers=None):
    """
    Evaluate Graph RAG on multiple test queries.

    Args:
        pdf_path (str): Path to the PDF document
        test_queries (List[str]): List of test queries
        reference_answers (List[str], optional): Reference answers for comparison

    Returns:
        Dict: Evaluation results
    """
    # Extract text from PDF
    text = extract_text_from_pdf(pdf_path)

    # Split text into chunks
    chunks = chunk_text(text)

    # Build knowledge graph (do this once for all queries)
    graph, embeddings = build_knowledge_graph(chunks)

    results = []

    for i, query in enumerate(test_queries):
        print(f"\n\n=== Evaluating Query {i+1}/{len(test_queries)} ===")
        print(f"Query: {query}")

        # Traverse graph to find relevant information
        relevant_chunks, traversal_path = traverse_graph(query, graph, embeddings)

        # Generate response
        response = generate_response(query, relevant_chunks)

        # Compare with reference answer if available
        reference = None
        comparison = None
        if reference_answers and i < len(reference_answers):
            reference = reference_answers[i]
            comparison = compare_with_reference(response, reference, query)

        # Append results for the current query
        results.append({
            "query": query,
            "response": response,
            "reference_answer": reference,
            "comparison": comparison,
            "traversal_path_length": len(traversal_path),
            "relevant_chunks_count": len(relevant_chunks)
        })

        # Display results
        print(f"\nResponse: {response}\n")
        if comparison:
            print(f"Comparison: {comparison}\n")

    # Return evaluation results and graph statistics
    return {
        "results": results,
        "graph_stats": {
            "nodes": graph.number_of_nodes(),
            "edges": graph.number_of_edges(),
            "avg_degree": sum(dict(graph.degree()).values()) / graph.number_of_nodes()
        }
    }

# %%
def compare_with_reference(response, reference, query):
    """
    Compare generated response with reference answer.

    Args:
        response (str): Generated response
        reference (str): Reference answer
        query (str): Original query

    Returns:
        str: Comparison analysis
    """
    # System message to instruct the model on how to compare the responses
    system_message = """Compare the AI-generated response with the reference answer.
Evaluate based on: correctness, completeness, and relevance to the query.
Provide a brief analysis (2-3 sentences) of how well the generated response matches the reference."""

    # Construct the prompt with the query, AI-generated response, and reference answer
    prompt = f"""
Query: {query}

AI-generated response:
{response}

Reference answer:
{reference}

How well does the AI response match the reference?
"""

    # Make a request to the OpenAI API to generate the comparison analysis
    comparison = gen(system_message, prompt, 0.2)

    # Return the generated comparison analysis
    return comparison

# %% [markdown]
# ## Evaluation of Graph RAG on a Sample PDF Document

# %%
# Path to the PDF document containing AI information
pdf_path = "AI_Information.pdf"

# Define an AI-related query for testing Graph RAG
query = "What are the key applications of transformers in natural language processing?"

# Execute the Graph RAG pipeline to process the document and answer the query
results = graph_rag_pipeline(pdf_path, query)

# Print the response generated from the Graph RAG system
print("\n=== ANSWER ===")
print(results["response"])

# Define a test query and reference answer for formal evaluation
test_queries = [
    "How do transformers handle sequential data compared to RNNs?"
]

# Reference answer for evaluation purposes
reference_answers = [
    "Transformers handle sequential data differently from RNNs by using self-attention mechanisms instead of recurrent connections. This allows transformers to process all tokens in parallel rather than sequentially, capturing long-range dependencies more efficiently and enabling better parallelization during training. Unlike RNNs, transformers don't suffer from vanishing gradient problems with long sequences."
]

# Run formal evaluation of the Graph RAG system with the test query
evaluation = evaluate_graph_rag(pdf_path, test_queries, reference_answers)

# Print evaluation summary statistics
print("\n=== EVALUATION SUMMARY ===")
print(f"Graph nodes: {evaluation['graph_stats']['nodes']}")
print(f"Graph edges: {evaluation['graph_stats']['edges']}")
for i, result in enumerate(evaluation['results']):
    print(f"\nQuery {i+1}: {result['query']}")
    print(f"Path length: {result['traversal_path_length']}")
    print(f"Chunks used: {result['relevant_chunks_count']}")
# Out:
# Extracting text from AI_Information.pdf...
# Created 42 text chunks
# Building knowledge graph...
# Creating embeddings for chunks...
# Adding nodes to the graph...
# Extracting concepts for chunk 1/42...
# Extracting concepts for chunk 2/42...
# Extracting concepts for chunk 3/42...
# Extracting concepts for chunk 4/42...
# Extracting concepts for chunk 5/42...
# Extracting concepts for chunk 6/42...
# Extracting concepts for chunk 7/42...
# Extracting concepts for chunk 8/42...
# Extracting concepts for chunk 9/42...
# Extracting concepts for chunk 10/42...
# Extracting concepts for chunk 11/42...
# Extracting concepts for chunk 12/42...
# Extracting concepts for chunk 13/42...
# Extracting concepts for chunk 14/42...
# Extracting concepts for chunk 15/42...
# Extracting concepts for chunk 16/42...
# Extracting concepts for chunk 17/42...
# Extracting concepts for chunk 18/42...
# Extracting concepts for chunk 19/42...
# Extracting concepts for chunk 20/42...
# Extracting concepts for chunk 21/42...
# Extracting concepts for chunk 22/42...
# Extracting concepts for chunk 23/42...
# Extracting concepts for chunk 24/42...
# Extracting concepts for chunk 25/42...
# Extracting concepts for chunk 26/42...
# Extracting concepts for chunk 27/42...
# Extracting concepts for chunk 28/42...
# Extracting concepts for chunk 29/42...
# Extracting concepts for chunk 30/42...
# Extracting concepts for chunk 31/42...
# Extracting concepts for chunk 32/42...
# Extracting concepts for chunk 33/42...
# Extracting concepts for chunk 34/42...
# Extracting concepts for chunk 35/42...
# Extracting concepts for chunk 36/42...
# Extracting concepts for chunk 37/42...
# Extracting concepts for chunk 38/42...
# Extracting concepts for chunk 39/42...
# Extracting concepts for chunk 40/42...
# Extracting concepts for chunk 41/42...
# Extracting concepts for chunk 42/42...
# Creating edges between nodes...
# {'Computing Power', 'Data Availability', 'Symbolic Methods', 'Reasoning', 'Artificial Intelligence'}
# ===intersec between 1 and 2===
# {'Artificial Intelligence'}
# ===intersec between 1 and 3===
# {'Artificial Intelligence'}
# ===intersec between 1 and 4===
# set()
# ===intersec between 1 and 5===
# set()
# ===intersec between 1 and 6===
# set()
# ===intersec between 1 and 7===
# {'Artificial Intelligence'}
# ===intersec between 1 and 8===
# set()
# ===intersec between 1 and 9===
# set()
# ===intersec between 1 and 10===
# set()
# ===intersec between 1 and 11===
# set()
# ===intersec between 1 and 12===
# set()
# ===intersec between 1 and 13===
# set()
# ===intersec between 1 and 14===
# set()
# ===intersec between 1 and 15===
# set()
# ===intersec between 1 and 16===
# set()
# ===intersec between 1 and 17===
# set()
# ===intersec between 1 and 18===
# set()
# ===intersec between 1 and 19===
# set()
# ===intersec between 1 and 20===
# set()
# ===intersec between 1 and 21===
# set()
# ===intersec between 1 and 22===
# set()
# ===intersec between 1 and 23===
# set()
# ===intersec between 1 and 24===
# set()
# ===intersec between 1 and 25===
# set()
# ===intersec between 1 and 26===
# set()
# ===intersec between 1 and 27===
# set()
# ===intersec between 1 and 28===
# set()
# ===intersec between 1 and 29===
# set()
# ===intersec between 1 and 30===
# set()
# ===intersec between 1 and 31===
# set()
# ===intersec between 1 and 32===
# set()
# ===intersec between 1 and 33===
# set()
# ===intersec between 1 and 34===
# set()
# ===intersec between 1 and 35===
# {'Artificial Intelligence'}
# ===intersec between 1 and 36===
# set()
# ===intersec between 1 and 37===
# set()
# ===intersec between 1 and 38===
# set()
# ===intersec between 1 and 39===
# set()
# ===intersec between 1 and 40===
# set()
# ===intersec between 1 and 41===
# set()
# ===intersec between 1 and 42===
# set()
# {'Machine Learning', 'Expert Systems', 'Deep Learning', 'Neural Networks', 'Artificial Intelligence'}
# ===intersec between 2 and 3===
# {'Artificial Intelligence', 'Machine Learning'}
# ===intersec between 2 and 4===
# {'Deep Learning'}
# ===intersec between 2 and 5===
# {'Deep Learning'}
# ===intersec between 2 and 6===
# {'Machine Learning'}
# ===intersec between 2 and 7===
# {'Artificial Intelligence', 'Machine Learning'}
# ===intersec between 2 and 8===
# set()
# ===intersec between 2 and 9===
# set()
# ===intersec between 2 and 10===
# set()
# ===intersec between 2 and 11===
# set()
# ===intersec between 2 and 12===
# set()
# ===intersec between 2 and 13===
# set()
# ===intersec between 2 and 14===
# set()
# ===intersec between 2 and 15===
# set()
# ===intersec between 2 and 16===
# set()
# ===intersec between 2 and 17===
# {'Machine Learning'}
# ===intersec between 2 and 18===
# set()
# ===intersec between 2 and 19===
# set()
# ===intersec between 2 and 20===
# set()
# ===intersec between 2 and 21===
# set()
# ===intersec between 2 and 22===
# set()
# ===intersec between 2 and 23===
# set()
# ===intersec between 2 and 24===
# set()
# ===intersec between 2 and 25===
# set()
# ===intersec between 2 and 26===
# set()
# ===intersec between 2 and 27===
# set()
# ===intersec between 2 and 28===
# set()
# ===intersec between 2 and 29===
# set()
# ===intersec between 2 and 30===
# {'Deep Learning'}
# ===intersec between 2 and 31===
# set()
# ===intersec between 2 and 32===
# set()
# ===intersec between 2 and 33===
# set()
# ===intersec between 2 and 34===
# set()
# ===intersec between 2 and 35===
# {'Artificial Intelligence'}
# ===intersec between 2 and 36===
# set()
# ===intersec between 2 and 37===
# set()
# ===intersec between 2 and 38===
# set()
# ===intersec between 2 and 39===
# set()
# ===intersec between 2 and 40===
# set()
# ===intersec between 2 and 41===
# set()
# ===intersec between 2 and 42===
# set()
# {'Machine Learning', 'Unsupervised Learning', 'Bias', 'Artificial Intelligence', 'Supervised Learning'}
# ===intersec between 3 and 4===
# {'Unsupervised Learning'}
# ===intersec between 3 and 5===
# set()
# ===intersec between 3 and 6===
# {'Machine Learning'}
# ===intersec between 3 and 7===
# {'Artificial Intelligence', 'Machine Learning'}
# ===intersec between 3 and 8===
# set()
# ===intersec between 3 and 9===
# {'Bias'}
# ===intersec between 3 and 10===
# set()
# ===intersec between 3 and 11===
# set()
# ===intersec between 3 and 12===
# set()
# ===intersec between 3 and 13===
# {'Bias'}
# ===intersec between 3 and 14===
# set()
# ===intersec between 3 and 15===
# set()
# ===intersec between 3 and 16===
# set()
# ===intersec between 3 and 17===
# {'Machine Learning'}
# ===intersec between 3 and 18===
# set()
# ===intersec between 3 and 19===
# set()
# ===intersec between 3 and 20===
# set()
# ===intersec between 3 and 21===
# set()
# ===intersec between 3 and 22===
# set()
# ===intersec between 3 and 23===
# set()
# ===intersec between 3 and 24===
# set()
# ===intersec between 3 and 25===
# set()
# ===intersec between 3 and 26===
# set()
# ===intersec between 3 and 27===
# set()
# ===intersec between 3 and 28===
# set()
# ===intersec between 3 and 29===
# set()
# ===intersec between 3 and 30===
# set()
# ===intersec between 3 and 31===
# set()
# ===intersec between 3 and 32===
# set()
# ===intersec between 3 and 33===
# set()
# ===intersec between 3 and 34===
# set()
# ===intersec between 3 and 35===
# {'Artificial Intelligence'}
# ===intersec between 3 and 36===
# {'Bias'}
# ===intersec between 3 and 37===
# {'Bias'}
# ===intersec between 3 and 38===
# set()
# ===intersec between 3 and 39===
# set()
# ===intersec between 3 and 40===
# set()
# ===intersec between 3 and 41===
# set()
# ===intersec between 3 and 42===
# set()
# {'Clustering', 'Deep Learning', 'Dimensionality Reduction', 'Unsupervised Learning', 'Reinforcement Learning'}
# ===intersec between 4 and 5===
# {'Deep Learning'}
# ===intersec between 4 and 6===
# set()
# ===intersec between 4 and 7===
# set()
# ===intersec between 4 and 8===
# set()
# ===intersec between 4 and 9===
# set()
# ===intersec between 4 and 10===
# set()
# ===intersec between 4 and 11===
# set()
# ===intersec between 4 and 12===
# set()
# ===intersec between 4 and 13===
# set()
# ===intersec between 4 and 14===
# set()
# ===intersec between 4 and 15===
# set()
# ===intersec between 4 and 16===
# {'Reinforcement Learning'}
# ===intersec between 4 and 17===
# set()
# ===intersec between 4 and 18===
# set()
# ===intersec between 4 and 19===
# set()
# ===intersec between 4 and 20===
# set()
# ===intersec between 4 and 21===
# set()
# ===intersec between 4 and 22===
# set()
# ===intersec between 4 and 23===
# set()
# ===intersec between 4 and 24===
# set()
# ===intersec between 4 and 25===
# set()
# ===intersec between 4 and 26===
# set()
# ===intersec between 4 and 27===
# set()
# ===intersec between 4 and 28===
# set()
# ===intersec between 4 and 29===
# set()
# ===intersec between 4 and 30===
# {'Deep Learning'}
# ===intersec between 4 and 31===
# set()
# ===intersec between 4 and 32===
# set()
# ===intersec between 4 and 33===
# set()
# ===intersec between 4 and 34===
# set()
# ===intersec between 4 and 35===
# set()
# ===intersec between 4 and 36===
# set()
# ===intersec between 4 and 37===
# set()
# ===intersec between 4 and 38===
# set()
# ===intersec between 4 and 39===
# set()
# ===intersec between 4 and 40===
# set()
# ===intersec between 4 and 41===
# set()
# ===intersec between 4 and 42===
# set()
# {'Image Recognition', 'Deep Learning', 'Convolutional Neural Networks (CNNs)', 'Recurrent Neural Networks (RNNs)', 'Natural Language Processing (NLP)'}
# ===intersec between 5 and 6===
# {'Natural Language Processing (NLP)'}
# ===intersec between 5 and 7===
# set()
# ===intersec between 5 and 8===
# set()
# ===intersec between 5 and 9===
# set()
# ===intersec between 5 and 10===
# set()
# ===intersec between 5 and 11===
# set()
# ===intersec between 5 and 12===
# set()
# ===intersec between 5 and 13===
# set()
# ===intersec between 5 and 14===
# set()
# ===intersec between 5 and 15===
# set()
# ===intersec between 5 and 16===
# set()
# ===intersec between 5 and 17===
# set()
# ===intersec between 5 and 18===
# set()
# ===intersec between 5 and 19===
# set()
# ===intersec between 5 and 20===
# set()
# ===intersec between 5 and 21===
# set()
# ===intersec between 5 and 22===
# set()
# ===intersec between 5 and 23===
# set()
# ===intersec between 5 and 24===
# set()
# ===intersec between 5 and 25===
# set()
# ===intersec between 5 and 26===
# set()
# ===intersec between 5 and 27===
# set()
# ===intersec between 5 and 28===
# set()
# ===intersec between 5 and 29===
# set()
# ===intersec between 5 and 30===
# {'Deep Learning'}
# ===intersec between 5 and 31===
# set()
# ===intersec between 5 and 32===
# set()
# ===intersec between 5 and 33===
# set()
# ===intersec between 5 and 34===
# set()
# ===intersec between 5 and 35===
# set()
# ===intersec between 5 and 36===
# set()
# ===intersec between 5 and 37===
# set()
# ===intersec between 5 and 38===
# set()
# ===intersec between 5 and 39===
# set()
# ===intersec between 5 and 40===
# set()
# ===intersec between 5 and 41===
# set()
# ===intersec between 5 and 42===
# set()
# {'Machine Learning', 'Artificial Intelligence (AI)', 'Computer Vision', 'Healthcare', 'Natural Language Processing (NLP)'}
# ===intersec between 6 and 7===
# {'Machine Learning'}
# ===intersec between 6 and 8===
# set()
# ===intersec between 6 and 9===
# set()
# ===intersec between 6 and 10===
# set()
# ===intersec between 6 and 11===
# {'Artificial Intelligence (AI)'}
# ===intersec between 6 and 12===
# set()
# ===intersec between 6 and 13===
# set()
# ===intersec between 6 and 14===
# set()
# ===intersec between 6 and 15===
# set()
# ===intersec between 6 and 16===
# {'Computer Vision'}
# ===intersec between 6 and 17===
# {'Machine Learning', 'Artificial Intelligence (AI)'}
# ===intersec between 6 and 18===
# {'Artificial Intelligence (AI)'}
# ===intersec between 6 and 19===
# set()
# ===intersec between 6 and 20===
# set()
# ===intersec between 6 and 21===
# set()
# ===intersec between 6 and 22===
# set()
# ===intersec between 6 and 23===
# set()
# ===intersec between 6 and 24===
# {'Artificial Intelligence (AI)'}
# ===intersec between 6 and 25===
# set()
# ===intersec between 6 and 26===
# set()
# ===intersec between 6 and 27===
# set()
# ===intersec between 6 and 28===
# set()
# ===intersec between 6 and 29===
# set()
# ===intersec between 6 and 30===
# set()
# ===intersec between 6 and 31===
# set()
# ===intersec between 6 and 32===
# {'Artificial Intelligence (AI)'}
# ===intersec between 6 and 33===
# set()
# ===intersec between 6 and 34===
# set()
# ===intersec between 6 and 35===
# set()
# ===intersec between 6 and 36===
# set()
# ===intersec between 6 and 37===
# set()
# ===intersec between 6 and 38===
# set()
# ===intersec between 6 and 39===
# set()
# ===intersec between 6 and 40===
# set()
# ===intersec between 6 and 41===
# set()
# ===intersec between 6 and 42===
# {'Artificial Intelligence (AI)'}
# {'Autonomous Vehicles', 'Machine Learning', 'Algorithmic Trading', 'Personalized Medicine', 'Artificial Intelligence'}
# ===intersec between 7 and 8===
# set()
# ===intersec between 7 and 9===
# set()
# ===intersec between 7 and 10===
# set()
# ===intersec between 7 and 11===
# set()
# ===intersec between 7 and 12===
# set()
# ===intersec between 7 and 13===
# set()
# ===intersec between 7 and 14===
# set()
# ===intersec between 7 and 15===
# set()
# ===intersec between 7 and 16===
# set()
# ===intersec between 7 and 17===
# {'Machine Learning'}
# ===intersec between 7 and 18===
# set()
# ===intersec between 7 and 19===
# set()
# ===intersec between 7 and 20===
# set()
# ===intersec between 7 and 21===
# set()
# ===intersec between 7 and 22===
# set()
# ===intersec between 7 and 23===
# set()
# ===intersec between 7 and 24===
# {'Personalized Medicine'}
# ===intersec between 7 and 25===
# set()
# ===intersec between 7 and 26===
# set()
# ===intersec between 7 and 27===
# set()
# ===intersec between 7 and 28===
# set()
# ===intersec between 7 and 29===
# set()
# ===intersec between 7 and 30===
# set()
# ===intersec between 7 and 31===
# set()
# ===intersec between 7 and 32===
# set()
# ===intersec between 7 and 33===
# set()
# ===intersec between 7 and 34===
# set()
# ===intersec between 7 and 35===
# {'Artificial Intelligence'}
# ===intersec between 7 and 36===
# set()
# ===intersec between 7 and 37===
# set()
# ===intersec between 7 and 38===
# set()
# ===intersec between 7 and 39===
# set()
# ===intersec between 7 and 40===
# set()
# ===intersec between 7 and 41===
# set()
# ===intersec between 7 and 42===
# set()
# {'Education', 'Cybersecurity', 'Manufacturing', 'Customer Data', 'AI'}
# ===intersec between 8 and 9===
# {'Cybersecurity', 'AI'}
# ===intersec between 8 and 10===
# set()
# ===intersec between 8 and 11===
# set()
# ===intersec between 8 and 12===
# set()
# ===intersec between 8 and 13===
# set()
# ===intersec between 8 and 14===
# {'AI'}
# ===intersec between 8 and 15===
# {'AI'}
# ===intersec between 8 and 16===
# set()
# ===intersec between 8 and 17===
# set()
# ===intersec between 8 and 18===
# set()
# ===intersec between 8 and 19===
# {'AI'}
# ===intersec between 8 and 20===
# {'AI'}
# ===intersec between 8 and 21===
# set()
# ===intersec between 8 and 22===
# {'AI'}
# ===intersec between 8 and 23===
# {'Education', 'AI'}
# ===intersec between 8 and 24===
# set()
# ===intersec between 8 and 25===
# {'Cybersecurity', 'AI'}
# ===intersec between 8 and 26===
# {'AI'}
# ===intersec between 8 and 27===
# set()
# ===intersec between 8 and 28===
# {'AI'}
# ===intersec between 8 and 29===
# {'AI'}
# ===intersec between 8 and 30===
# {'AI'}
# ===intersec between 8 and 31===
# {'AI'}
# ===intersec between 8 and 32===
# set()
# ===intersec between 8 and 33===
# set()
# ===intersec between 8 and 34===
# {'AI'}
# ===intersec between 8 and 35===
# {'AI'}
# ===intersec between 8 and 36===
# set()
# ===intersec between 8 and 37===
# {'AI'}
# ===intersec between 8 and 38===
# set()
# ===intersec between 8 and 39===
# set()
# ===intersec between 8 and 40===
# {'AI'}
# ===intersec between 8 and 41===
# set()
# ===intersec between 8 and 42===
# set()
# {'Cybersecurity', 'Transparency', 'Bias', 'Fairness', 'AI'}
# ===intersec between 9 and 10===
# {'Transparency'}
# ===intersec between 9 and 11===
# set()
# ===intersec between 9 and 12===
# set()
# ===intersec between 9 and 13===
# {'Bias'}
# ===intersec between 9 and 14===
# {'AI'}
# ===intersec between 9 and 15===
# {'AI'}
# ===intersec between 9 and 16===
# set()
# ===intersec between 9 and 17===
# set()
# ===intersec between 9 and 18===
# set()
# ===intersec between 9 and 19===
# {'AI'}
# ===intersec between 9 and 20===
# {'AI'}
# ===intersec between 9 and 21===
# set()
# ===intersec between 9 and 22===
# {'AI'}
# ===intersec between 9 and 23===
# {'AI'}
# ===intersec between 9 and 24===
# set()
# ===intersec between 9 and 25===
# {'Cybersecurity', 'AI'}
# ===intersec between 9 and 26===
# {'AI'}
# ===intersec between 9 and 27===
# set()
# ===intersec between 9 and 28===
# {'Transparency', 'AI'}
# ===intersec between 9 and 29===
# {'AI'}
# ===intersec between 9 and 30===
# {'AI'}
# ===intersec between 9 and 31===
# {'AI'}
# ===intersec between 9 and 32===
# set()
# ===intersec between 9 and 33===
# set()
# ===intersec between 9 and 34===
# {'AI'}
# ===intersec between 9 and 35===
# {'AI'}
# ===intersec between 9 and 36===
# {'Transparency', 'Bias'}
# ===intersec between 9 and 37===
# {'Transparency', 'AI', 'Bias'}
# ===intersec between 9 and 38===
# {'Transparency'}
# ===intersec between 9 and 39===
# {'Transparency'}
# ===intersec between 9 and 40===
# {'AI'}
# ===intersec between 9 and 41===
# set()
# ===intersec between 9 and 42===
# set()
# {'Explainability', 'Transparency', 'Job Displacement', 'Privacy', 'Autonomy'}
# ===intersec between 10 and 11===
# set()
# ===intersec between 10 and 12===
# set()
# ===intersec between 10 and 13===
# {'Privacy'}
# ===intersec between 10 and 14===
# set()
# ===intersec between 10 and 15===
# set()
# ===intersec between 10 and 16===
# set()
# ===intersec between 10 and 17===
# set()
# ===intersec between 10 and 18===
# set()
# ===intersec between 10 and 19===
# set()
# ===intersec between 10 and 20===
# set()
# ===intersec between 10 and 21===
# set()
# ===intersec between 10 and 22===
# set()
# ===intersec between 10 and 23===
# set()
# ===intersec between 10 and 24===
# set()
# ===intersec between 10 and 25===
# set()
# ===intersec between 10 and 26===
# set()
# ===intersec between 10 and 27===
# set()
# ===intersec between 10 and 28===
# {'Transparency'}
# ===intersec between 10 and 29===
# set()
# ===intersec between 10 and 30===
# set()
# ===intersec between 10 and 31===
# set()
# ===intersec between 10 and 32===
# set()
# ===intersec between 10 and 33===
# set()
# ===intersec between 10 and 34===
# set()
# ===intersec between 10 and 35===
# set()
# ===intersec between 10 and 36===
# {'Transparency'}
# ===intersec between 10 and 37===
# {'Explainability', 'Transparency'}
# ===intersec between 10 and 38===
# {'Explainability', 'Transparency', 'Privacy'}
# ===intersec between 10 and 39===
# {'Transparency'}
# ===intersec between 10 and 40===
# set()
# ===intersec between 10 and 41===
# set()
# ===intersec between 10 and 42===
# set()
# {'Explainable AI (XAI)', 'Artificial Intelligence (AI)', 'International regulations', 'Autonomous weapons systems', 'Accountability'}
# ===intersec between 11 and 12===
# set()
# ===intersec between 11 and 13===
# set()
# ===intersec between 11 and 14===
# set()
# ===intersec between 11 and 15===
# set()
# ===intersec between 11 and 16===
# set()
# ===intersec between 11 and 17===
# {'Artificial Intelligence (AI)'}
# ===intersec between 11 and 18===
# {'Artificial Intelligence (AI)'}
# ===intersec between 11 and 19===
# set()
# ===intersec between 11 and 20===
# set()
# ===intersec between 11 and 21===
# set()
# ===intersec between 11 and 22===
# set()
# ===intersec between 11 and 23===
# set()
# ===intersec between 11 and 24===
# {'Artificial Intelligence (AI)'}
# ===intersec between 11 and 25===
# set()
# ===intersec between 11 and 26===
# set()
# ===intersec between 11 and 27===
# set()
# ===intersec between 11 and 28===
# set()
# ===intersec between 11 and 29===
# set()
# ===intersec between 11 and 30===
# {'Explainable AI (XAI)'}
# ===intersec between 11 and 31===
# {'Accountability'}
# ===intersec between 11 and 32===
# {'Artificial Intelligence (AI)'}
# ===intersec between 11 and 33===
# set()
# ===intersec between 11 and 34===
# set()
# ===intersec between 11 and 35===
# set()
# ===intersec between 11 and 36===
# set()
# ===intersec between 11 and 37===
# set()
# ===intersec between 11 and 38===
# {'Explainable AI (XAI)', 'Accountability'}
# ===intersec between 11 and 39===
# set()
# ===intersec between 11 and 40===
# set()
# ===intersec between 11 and 41===
# set()
# ===intersec between 11 and 42===
# {'Artificial Intelligence (AI)'}
# {'AI at the Edge', 'Human-AI Collaboration', 'Trust and Accountability', 'Quantum Computing', 'AI for Social Good'}
# ===intersec between 12 and 13===
# {'AI for Social Good'}
# ===intersec between 12 and 14===
# set()
# ===intersec between 12 and 15===
# set()
# ===intersec between 12 and 16===
# set()
# ===intersec between 12 and 17===
# set()
# ===intersec between 12 and 18===
# set()
# ===intersec between 12 and 19===
# set()
# ===intersec between 12 and 20===
# set()
# ===intersec between 12 and 21===
# set()
# ===intersec between 12 and 22===
# set()
# ===intersec between 12 and 23===
# set()
# ===intersec between 12 and 24===
# set()
# ===intersec between 12 and 25===
# set()
# ===intersec between 12 and 26===
# set()
# ===intersec between 12 and 27===
# {'AI for Social Good'}
# ===intersec between 12 and 28===
# set()
# ===intersec between 12 and 29===
# set()
# ===intersec between 12 and 30===
# set()
# ===intersec between 12 and 31===
# set()
# ===intersec between 12 and 32===
# set()
# ===intersec between 12 and 33===
# set()
# ===intersec between 12 and 34===
# set()
# ===intersec between 12 and 35===
# set()
# ===intersec between 12 and 36===
# set()
# ===intersec between 12 and 37===
# set()
# ===intersec between 12 and 38===
# set()
# ===intersec between 12 and 39===
# set()
# ===intersec between 12 and 40===
# set()
# ===intersec between 12 and 41===
# set()
# ===intersec between 12 and 42===
# set()
# {'Governance', 'Privacy', 'Bias', 'Regulation', 'AI for Social Good'}
# ===intersec between 13 and 14===
# set()
# ===intersec between 13 and 15===
# set()
# ===intersec between 13 and 16===
# set()
# ===intersec between 13 and 17===
# set()
# ===intersec between 13 and 18===
# set()
# ===intersec between 13 and 19===
# set()
# ===intersec between 13 and 20===
# set()
# ===intersec between 13 and 21===
# set()
# ===intersec between 13 and 22===
# set()
# ===intersec between 13 and 23===
# set()
# ===intersec between 13 and 24===
# set()
# ===intersec between 13 and 25===
# set()
# ===intersec between 13 and 26===
# set()
# ===intersec between 13 and 27===
# {'AI for Social Good'}
# ===intersec between 13 and 28===
# set()
# ===intersec between 13 and 29===
# set()
# ===intersec between 13 and 30===
# set()
# ===intersec between 13 and 31===
# set()
# ===intersec between 13 and 32===
# set()
# ===intersec between 13 and 33===
# set()
# ===intersec between 13 and 34===
# set()
# ===intersec between 13 and 35===
# {'Regulation'}
# ===intersec between 13 and 36===
# {'Bias'}
# ===intersec between 13 and 37===
# {'Bias'}
# ===intersec between 13 and 38===
# {'Privacy'}
# ===intersec between 13 and 39===
# set()
# ===intersec between 13 and 40===
# set()
# ===intersec between 13 and 41===
# set()
# ===intersec between 13 and 42===
# set()
# {'Industrial Robots', 'Robotics', 'Cognitive Abilities', 'AI', 'Cobots'}
# ===intersec between 14 and 15===
# {'AI', 'Cobots'}
# ===intersec between 14 and 16===
# set()
# ===intersec between 14 and 17===
# set()
# ===intersec between 14 and 18===
# set()
# ===intersec between 14 and 19===
# {'AI'}
# ===intersec between 14 and 20===
# {'AI'}
# ===intersec between 14 and 21===
# set()
# ===intersec between 14 and 22===
# {'AI'}
# ===intersec between 14 and 23===
# {'AI'}
# ===intersec between 14 and 24===
# set()
# ===intersec between 14 and 25===
# {'AI'}
# ===intersec between 14 and 26===
# {'AI'}
# ===intersec between 14 and 27===
# set()
# ===intersec between 14 and 28===
# {'AI'}
# ===intersec between 14 and 29===
# {'AI'}
# ===intersec between 14 and 30===
# {'AI'}
# ===intersec between 14 and 31===
# {'AI'}
# ===intersec between 14 and 32===
# set()
# ===intersec between 14 and 33===
# set()
# ===intersec between 14 and 34===
# {'AI'}
# ===intersec between 14 and 35===
# {'AI'}
# ===intersec between 14 and 36===
# set()
# ===intersec between 14 and 37===
# {'AI'}
# ===intersec between 14 and 38===
# set()
# ===intersec between 14 and 39===
# set()
# ===intersec between 14 and 40===
# {'AI'}
# ===intersec between 14 and 41===
# set()
# ===intersec between 14 and 42===
# set()
# {'Imitation Learning', 'Surgical Robots', 'Service Robots', 'AI', 'Cobots'}
# ===intersec between 15 and 16===
# set()
# ===intersec between 15 and 17===
# set()
# ===intersec between 15 and 18===
# set()
# ===intersec between 15 and 19===
# {'AI'}
# ===intersec between 15 and 20===
# {'AI'}
# ===intersec between 15 and 21===
# set()
# ===intersec between 15 and 22===
# {'AI'}
# ===intersec between 15 and 23===
# {'AI'}
# ===intersec between 15 and 24===
# set()
# ===intersec between 15 and 25===
# {'AI'}
# ===intersec between 15 and 26===
# {'AI'}
# ===intersec between 15 and 27===
# set()
# ===intersec between 15 and 28===
# {'AI'}
# ===intersec between 15 and 29===
# {'AI'}
# ===intersec between 15 and 30===
# {'AI'}
# ===intersec between 15 and 31===
# {'AI'}
# ===intersec between 15 and 32===
# set()
# ===intersec between 15 and 33===
# set()
# ===intersec between 15 and 34===
# {'AI'}
# ===intersec between 15 and 35===
# {'AI'}
# ===intersec between 15 and 36===
# set()
# ===intersec between 15 and 37===
# {'AI'}
# ===intersec between 15 and 38===
# set()
# ===intersec between 15 and 39===
# set()
# ===intersec between 15 and 40===
# {'AI'}
# ===intersec between 15 and 41===
# set()
# ===intersec between 15 and 42===
# set()
# {'Robot Navigation', 'SLAM (Simultaneous Localization and Mapping)', 'Computer Vision', 'Autonomous Systems', 'Reinforcement Learning'}
# ===intersec between 16 and 17===
# set()
# ===intersec between 16 and 18===
# set()
# ===intersec between 16 and 19===
# set()
# ===intersec between 16 and 20===
# set()
# ===intersec between 16 and 21===
# set()
# ===intersec between 16 and 22===
# set()
# ===intersec between 16 and 23===
# set()
# ===intersec between 16 and 24===
# set()
# ===intersec between 16 and 25===
# set()
# ===intersec between 16 and 26===
# set()
# ===intersec between 16 and 27===
# set()
# ===intersec between 16 and 28===
# set()
# ===intersec between 16 and 29===
# set()
# ===intersec between 16 and 30===
# set()
# ===intersec between 16 and 31===
# set()
# ===intersec between 16 and 32===
# set()
# ===intersec between 16 and 33===
# set()
# ===intersec between 16 and 34===
# set()
# ===intersec between 16 and 35===
# set()
# ===intersec between 16 and 36===
# set()
# ===intersec between 16 and 37===
# set()
# ===intersec between 16 and 38===
# set()
# ===intersec between 16 and 39===
# set()
# ===intersec between 16 and 40===
# set()
# ===intersec between 16 and 41===
# set()
# ===intersec between 16 and 42===
# set()
# {'Machine Learning', 'Artificial Intelligence (AI)', 'Customer Relationship Management (CRM)', 'Supply Chain Management', 'Object recognition'}
# ===intersec between 17 and 18===
# {'Supply Chain Management', 'Artificial Intelligence (AI)'}
# ===intersec between 17 and 19===
# set()
# ===intersec between 17 and 20===
# set()
# ===intersec between 17 and 21===
# set()
# ===intersec between 17 and 22===
# set()
# ===intersec between 17 and 23===
# set()
# ===intersec between 17 and 24===
# {'Artificial Intelligence (AI)'}
# ===intersec between 17 and 25===
# set()
# ===intersec between 17 and 26===
# set()
# ===intersec between 17 and 27===
# set()
# ===intersec between 17 and 28===
# set()
# ===intersec between 17 and 29===
# set()
# ===intersec between 17 and 30===
# set()
# ===intersec between 17 and 31===
# set()
# ===intersec between 17 and 32===
# {'Artificial Intelligence (AI)'}
# ===intersec between 17 and 33===
# set()
# ===intersec between 17 and 34===
# set()
# ===intersec between 17 and 35===
# set()
# ===intersec between 17 and 36===
# set()
# ===intersec between 17 and 37===
# set()
# ===intersec between 17 and 38===
# set()
# ===intersec between 17 and 39===
# set()
# ===intersec between 17 and 40===
# set()
# ===intersec between 17 and 41===
# set()
# ===intersec between 17 and 42===
# {'Artificial Intelligence (AI)'}
# {'Marketing', 'Artificial Intelligence (AI)', 'Human Resources (HR)', 'Supply Chain Management', 'Financial Services'}
# ===intersec between 18 and 19===
# set()
# ===intersec between 18 and 20===
# set()
# ===intersec between 18 and 21===
# set()
# ===intersec between 18 and 22===
# set()
# ===intersec between 18 and 23===
# set()
# ===intersec between 18 and 24===
# {'Artificial Intelligence (AI)'}
# ===intersec between 18 and 25===
# set()
# ===intersec between 18 and 26===
# set()
# ===intersec between 18 and 27===
# set()
# ===intersec between 18 and 28===
# set()
# ===intersec between 18 and 29===
# set()
# ===intersec between 18 and 30===
# set()
# ===intersec between 18 and 31===
# set()
# ===intersec between 18 and 32===
# {'Artificial Intelligence (AI)'}
# ===intersec between 18 and 33===
# set()
# ===intersec between 18 and 34===
# set()
# ===intersec between 18 and 35===
# set()
# ===intersec between 18 and 36===
# set()
# ===intersec between 18 and 37===
# set()
# ===intersec between 18 and 38===
# set()
# ===intersec between 18 and 39===
# set()
# ===intersec between 18 and 40===
# set()
# ===intersec between 18 and 41===
# set()
# ===intersec between 18 and 42===
# {'Artificial Intelligence (AI)'}
# {'Automation', 'Customer service', 'Algorithmic trading', 'Reskilling', 'AI'}
# ===intersec between 19 and 20===
# {'AI'}
# ===intersec between 19 and 21===
# set()
# ===intersec between 19 and 22===
# {'AI'}
# ===intersec between 19 and 23===
# {'AI'}
# ===intersec between 19 and 24===
# set()
# ===intersec between 19 and 25===
# {'AI'}
# ===intersec between 19 and 26===
# {'AI'}
# ===intersec between 19 and 27===
# set()
# ===intersec between 19 and 28===
# {'AI'}
# ===intersec between 19 and 29===
# {'AI'}
# ===intersec between 19 and 30===
# {'AI'}
# ===intersec between 19 and 31===
# {'AI'}
# ===intersec between 19 and 32===
# set()
# ===intersec between 19 and 33===
# set()
# ===intersec between 19 and 34===
# {'AI'}
# ===intersec between 19 and 35===
# {'AI'}
# ===intersec between 19 and 36===
# set()
# ===intersec between 19 and 37===
# {'AI'}
# ===intersec between 19 and 38===
# set()
# ===intersec between 19 and 39===
# set()
# ===intersec between 19 and 40===
# {'AI'}
# ===intersec between 19 and 41===
# set()
# ===intersec between 19 and 42===
# {'Reskilling'}
# {'Ethics', 'Collaboration', 'Creativity', 'Job Roles', 'AI'}
# ===intersec between 20 and 21===
# set()
# ===intersec between 20 and 22===
# {'AI'}
# ===intersec between 20 and 23===
# {'AI'}
# ===intersec between 20 and 24===
# set()
# ===intersec between 20 and 25===
# {'AI'}
# ===intersec between 20 and 26===
# {'AI'}
# ===intersec between 20 and 27===
# set()
# ===intersec between 20 and 28===
# {'AI'}
# ===intersec between 20 and 29===
# {'AI'}
# ===intersec between 20 and 30===
# {'AI'}
# ===intersec between 20 and 31===
# {'AI'}
# ===intersec between 20 and 32===
# set()
# ===intersec between 20 and 33===
# set()
# ===intersec between 20 and 34===
# {'AI'}
# ===intersec between 20 and 35===
# {'AI'}
# ===intersec between 20 and 36===
# {'Ethics'}
# ===intersec between 20 and 37===
# {'AI', 'Ethics'}
# ===intersec between 20 and 38===
# set()
# ===intersec between 20 and 39===
# set()
# ===intersec between 20 and 40===
# {'AI', 'Ethics'}
# ===intersec between 20 and 41===
# {'Ethics'}
# ===intersec between 20 and 42===
# set()
# {'AI in Writing and Content Creation', 'AI Algorithms', 'AI-Generated Art', 'AI-Driven Innovation', 'AI in Music Composition'}
# ===intersec between 21 and 22===
# set()
# ===intersec between 21 and 23===
# set()
# ===intersec between 21 and 24===
# set()
# ===intersec between 21 and 25===
# set()
# ===intersec between 21 and 26===
# set()
# ===intersec between 21 and 27===
# set()
# ===intersec between 21 and 28===
# set()
# ===intersec between 21 and 29===
# set()
# ===intersec between 21 and 30===
# set()
# ===intersec between 21 and 31===
# set()
# ===intersec between 21 and 32===
# set()
# ===intersec between 21 and 33===
# set()
# ===intersec between 21 and 34===
# set()
# ===intersec between 21 and 35===
# set()
# ===intersec between 21 and 36===
# set()
# ===intersec between 21 and 37===
# set()
# ===intersec between 21 and 38===
# set()
# ===intersec between 21 and 39===
# set()
# ===intersec between 21 and 40===
# set()
# ===intersec between 21 and 41===
# set()
# ===intersec between 21 and 42===
# set()
# {'Virtual Tutors', 'Adaptive Assessments', 'Personalized Learning', 'AI-powered tools', 'AI'}
# ===intersec between 22 and 23===
# {'AI'}
# ===intersec between 22 and 24===
# set()
# ===intersec between 22 and 25===
# {'AI'}
# ===intersec between 22 and 26===
# {'AI'}
# ===intersec between 22 and 27===
# set()
# ===intersec between 22 and 28===
# {'AI'}
# ===intersec between 22 and 29===
# {'AI'}
# ===intersec between 22 and 30===
# {'AI'}
# ===intersec between 22 and 31===
# {'AI'}
# ===intersec between 22 and 32===
# set()
# ===intersec between 22 and 33===
# set()
# ===intersec between 22 and 34===
# {'AI'}
# ===intersec between 22 and 35===
# {'AI'}
# ===intersec between 22 and 36===
# set()
# ===intersec between 22 and 37===
# {'AI'}
# ===intersec between 22 and 38===
# set()
# ===intersec between 22 and 39===
# set()
# ===intersec between 22 and 40===
# {'AI'}
# ===intersec between 22 and 41===
# set()
# ===intersec between 22 and 42===
# set()
# {'Medical Diagnosis', 'Educational Data Mining', 'Education', 'Automated Grading', 'AI'}
# ===intersec between 23 and 24===
# set()
# ===intersec between 23 and 25===
# {'AI'}
# ===intersec between 23 and 26===
# {'AI'}
# ===intersec between 23 and 27===
# set()
# ===intersec between 23 and 28===
# {'AI'}
# ===intersec between 23 and 29===
# {'AI'}
# ===intersec between 23 and 30===
# {'AI'}
# ===intersec between 23 and 31===
# {'AI'}
# ===intersec between 23 and 32===
# set()
# ===intersec between 23 and 33===
# set()
# ===intersec between 23 and 34===
# {'AI'}
# ===intersec between 23 and 35===
# {'AI'}
# ===intersec between 23 and 36===
# set()
# ===intersec between 23 and 37===
# {'AI'}
# ===intersec between 23 and 38===
# set()
# ===intersec between 23 and 39===
# set()
# ===intersec between 23 and 40===
# {'AI'}
# ===intersec between 23 and 41===
# set()
# ===intersec between 23 and 42===
# set()
# {'Drug Discovery', 'Artificial Intelligence (AI)', 'Robotic Surgery', 'Personalized Medicine', 'Medical Imaging'}
# ===intersec between 24 and 25===
# set()
# ===intersec between 24 and 26===
# set()
# ===intersec between 24 and 27===
# set()
# ===intersec between 24 and 28===
# set()
# ===intersec between 24 and 29===
# set()
# ===intersec between 24 and 30===
# set()
# ===intersec between 24 and 31===
# set()
# ===intersec between 24 and 32===
# {'Artificial Intelligence (AI)'}
# ===intersec between 24 and 33===
# set()
# ===intersec between 24 and 34===
# set()
# ===intersec between 24 and 35===
# set()
# ===intersec between 24 and 36===
# set()
# ===intersec between 24 and 37===
# set()
# ===intersec between 24 and 38===
# set()
# ===intersec between 24 and 39===
# set()
# ===intersec between 24 and 40===
# set()
# ===intersec between 24 and 41===
# set()
# ===intersec between 24 and 42===
# {'Artificial Intelligence (AI)'}
# {'Anomaly Detection', 'Cybersecurity', 'Fraud Detection', 'AI', 'Healthcare Administration'}
# ===intersec between 25 and 26===
# {'Fraud Detection', 'AI'}
# ===intersec between 25 and 27===
# set()
# ===intersec between 25 and 28===
# {'AI'}
# ===intersec between 25 and 29===
# {'AI'}
# ===intersec between 25 and 30===
# {'AI'}
# ===intersec between 25 and 31===
# {'AI'}
# ===intersec between 25 and 32===
# set()
# ===intersec between 25 and 33===
# set()
# ===intersec between 25 and 34===
# {'AI'}
# ===intersec between 25 and 35===
# {'AI'}
# ===intersec between 25 and 36===
# set()
# ===intersec between 25 and 37===
# {'AI'}
# ===intersec between 25 and 38===
# set()
# ===intersec between 25 and 39===
# set()
# ===intersec between 25 and 40===
# {'AI'}
# ===intersec between 25 and 41===
# set()
# ===intersec between 25 and 42===
# set()
# {'Cyberattacks', 'Fraud Detection', 'Vulnerability Management', 'Incident Response', 'AI'}
# ===intersec between 26 and 27===
# set()
# ===intersec between 26 and 28===
# {'AI'}
# ===intersec between 26 and 29===
# {'AI'}
# ===intersec between 26 and 30===
# {'AI'}
# ===intersec between 26 and 31===
# {'AI'}
# ===intersec between 26 and 32===
# set()
# ===intersec between 26 and 33===
# set()
# ===intersec between 26 and 34===
# {'AI'}
# ===intersec between 26 and 35===
# {'AI'}
# ===intersec between 26 and 36===
# set()
# ===intersec between 26 and 37===
# {'AI'}
# ===intersec between 26 and 38===
# set()
# ===intersec between 26 and 39===
# set()
# ===intersec between 26 and 40===
# {'AI'}
# ===intersec between 26 and 41===
# set()
# ===intersec between 26 and 42===
# set()
# {'Ethical Considerations', 'Poverty', 'Healthcare Disparities', 'Climate Change', 'AI for Social Good'}
# ===intersec between 27 and 28===
# set()
# ===intersec between 27 and 29===
# set()
# ===intersec between 27 and 30===
# set()
# ===intersec between 27 and 31===
# set()
# ===intersec between 27 and 32===
# set()
# ===intersec between 27 and 33===
# set()
# ===intersec between 27 and 34===
# set()
# ===intersec between 27 and 35===
# set()
# ===intersec between 27 and 36===
# set()
# ===intersec between 27 and 37===
# set()
# ===intersec between 27 and 38===
# set()
# ===intersec between 27 and 39===
# set()
# ===intersec between 27 and 40===
# set()
# ===intersec between 27 and 41===
# set()
# ===intersec between 27 and 42===
# set()
# {'Trust', 'Transparency', 'Urban Planning', 'Global Collaboration', 'AI'}
# ===intersec between 28 and 29===
# {'AI'}
# ===intersec between 28 and 30===
# {'AI'}
# ===intersec between 28 and 31===
# {'AI'}
# ===intersec between 28 and 32===
# set()
# ===intersec between 28 and 33===
# set()
# ===intersec between 28 and 34===
# {'AI'}
# ===intersec between 28 and 35===
# {'AI'}
# ===intersec between 28 and 36===
# {'Transparency'}
# ===intersec between 28 and 37===
# {'Transparency', 'AI'}
# ===intersec between 28 and 38===
# {'Transparency'}
# ===intersec between 28 and 39===
# {'Transparency'}
# ===intersec between 28 and 40===
# {'AI', 'Trust'}
# ===intersec between 28 and 41===
# {'Global Collaboration'}
# ===intersec between 28 and 42===
# set()
# {'Energy Management', 'Smart Transportation', 'Public Safety and Security', 'Environmental Monitoring', 'AI'}
# ===intersec between 29 and 30===
# {'Environmental Monitoring', 'AI'}
# ===intersec between 29 and 31===
# {'AI'}
# ===intersec between 29 and 32===
# set()
# ===intersec between 29 and 33===
# set()
# ===intersec between 29 and 34===
# {'Environmental Monitoring', 'AI'}
# ===intersec between 29 and 35===
# {'AI'}
# ===intersec between 29 and 36===
# set()
# ===intersec between 29 and 37===
# {'AI'}
# ===intersec between 29 and 38===
# set()
# ===intersec between 29 and 39===
# set()
# ===intersec between 29 and 40===
# {'AI'}
# ===intersec between 29 and 41===
# set()
# ===intersec between 29 and 42===
# set()
# {'Explainable AI (XAI)', 'Deep Learning', 'Neuroscience', 'Environmental Monitoring', 'AI'}
# ===intersec between 30 and 31===
# {'AI', 'Neuroscience'}
# ===intersec between 30 and 32===
# set()
# ===intersec between 30 and 33===
# set()
# ===intersec between 30 and 34===
# {'Environmental Monitoring', 'AI'}
# ===intersec between 30 and 35===
# {'AI'}
# ===intersec between 30 and 36===
# set()
# ===intersec between 30 and 37===
# {'AI'}
# ===intersec between 30 and 38===
# {'Explainable AI (XAI)'}
# ===intersec between 30 and 39===
# set()
# ===intersec between 30 and 40===
# {'AI'}
# ===intersec between 30 and 41===
# set()
# ===intersec between 30 and 42===
# set()
# {'Human-Centered AI', 'Generative AI', 'Neuroscience', 'Accountability', 'AI'}
# ===intersec between 31 and 32===
# set()
# ===intersec between 31 and 33===
# set()
# ===intersec between 31 and 34===
# {'AI'}
# ===intersec between 31 and 35===
# {'AI'}
# ===intersec between 31 and 36===
# set()
# ===intersec between 31 and 37===
# {'AI'}
# ===intersec between 31 and 38===
# {'Accountability'}
# ===intersec between 31 and 39===
# set()
# ===intersec between 31 and 40===
# {'AI'}
# ===intersec between 31 and 41===
# set()
# ===intersec between 31 and 42===
# set()
# {'Transformers', 'Generative Adversarial Networks (GANs)', 'Artificial Intelligence (AI)', 'AI-driven creativity', 'Collaborative AI'}
# ===intersec between 32 and 33===
# set()
# ===intersec between 32 and 34===
# set()
# ===intersec between 32 and 35===
# set()
# ===intersec between 32 and 36===
# set()
# ===intersec between 32 and 37===
# set()
# ===intersec between 32 and 38===
# set()
# ===intersec between 32 and 39===
# set()
# ===intersec between 32 and 40===
# set()
# ===intersec between 32 and 41===
# set()
# ===intersec between 32 and 42===
# {'Artificial Intelligence (AI)'}
# {'AI in Visual Arts and Design', 'Climate Change Mitigation', 'Precision Agriculture', 'AI in Interactive Media', 'Audio Mixing and Mastering'}
# ===intersec between 33 and 34===
# {'Precision Agriculture'}
# ===intersec between 33 and 35===
# set()
# ===intersec between 33 and 36===
# set()
# ===intersec between 33 and 37===
# set()
# ===intersec between 33 and 38===
# set()
# ===intersec between 33 and 39===
# set()
# ===intersec between 33 and 40===
# set()
# ===intersec between 33 and 41===
# set()
# ===intersec between 33 and 42===
# set()
# {'Wildlife Conservation', 'Precision Agriculture', 'Environmental Monitoring', 'Carbon Capture and Storage', 'AI'}
# ===intersec between 34 and 35===
# {'AI'}
# ===intersec between 34 and 36===
# set()
# ===intersec between 34 and 37===
# {'AI'}
# ===intersec between 34 and 38===
# set()
# ===intersec between 34 and 39===
# set()
# ===intersec between 34 and 40===
# {'AI'}
# ===intersec between 34 and 41===
# set()
# ===intersec between 34 and 42===
# set()
# {'Government Policy', 'Disaster Response', 'Regulation', 'Artificial Intelligence', 'AI'}
# ===intersec between 35 and 36===
# set()
# ===intersec between 35 and 37===
# {'AI'}
# ===intersec between 35 and 38===
# set()
# ===intersec between 35 and 39===
# set()
# ===intersec between 35 and 40===
# {'AI'}
# ===intersec between 35 and 41===
# set()
# ===intersec between 35 and 42===
# set()
# {'International Cooperation', 'Transparency', 'Ethics', 'Bias', 'Public Engagement'}
# ===intersec between 36 and 37===
# {'Transparency', 'Ethics', 'Bias'}
# ===intersec between 36 and 38===
# {'Transparency'}
# ===intersec between 36 and 39===
# {'Transparency'}
# ===intersec between 36 and 40===
# {'Ethics', 'Public Engagement'}
# ===intersec between 36 and 41===
# {'Ethics'}
# ===intersec between 36 and 42===
# set()
# {'Explainability', 'Transparency', 'Ethics', 'Bias', 'AI'}
# ===intersec between 37 and 38===
# {'Explainability', 'Transparency'}
# ===intersec between 37 and 39===
# {'Transparency'}
# ===intersec between 37 and 40===
# {'AI', 'Ethics'}
# ===intersec between 37 and 41===
# {'Ethics'}
# ===intersec between 37 and 42===
# set()
# {'Explainable AI (XAI)', 'Explainability', 'Transparency', 'Privacy', 'Accountability'}
# ===intersec between 38 and 39===
# {'Transparency'}
# ===intersec between 38 and 40===
# set()
# ===intersec between 38 and 41===
# set()
# ===intersec between 38 and 42===
# set()
# {'Reliability', 'Transparency', 'Ethical Design', 'User Control', 'Robustness'}
# ===intersec between 39 and 40===
# set()
# ===intersec between 39 and 41===
# set()
# ===intersec between 39 and 42===
# set()
# {'Trust', 'Ethics', 'Research', 'Public Engagement', 'AI'}
# ===intersec between 40 and 41===
# {'Ethics'}
# ===intersec between 40 and 42===
# set()
# {'Education and Workforce Development', 'Human-Centered Approach', 'Ethics', 'Responsible AI', 'Global Collaboration'}
# ===intersec between 41 and 42===
# {'Human-Centered Approach'}
# {'Artificial Intelligence (AI)', 'Human-Centered Approach', 'Lifelong Learning', 'Reskilling', 'Upskilling'}
# Knowledge graph built with 42 nodes and 45 edges
# Traversing graph for query: What are the key applications of transformers in natural language processing?
# Starting traversal from 3 nodes
# Graph traversal found 3 relevant chunks
# === ANSWER ===
# There is no mention of transformers in the provided context. The context only discusses Convolutional Neural Networks (CNNs), Recurrent Neural Networks (RNNs), Natural Language Processing (NLP), Computer Vision, and various applications of Artificial Intelligence (AI) across different domains. Transformers are not mentioned.
# Extracting text from AI_Information.pdf...
# Created 42 text chunks
# Building knowledge graph...
# Creating embeddings for chunks...
# Adding nodes to the graph...
# Extracting concepts for chunk 1/42...
# Extracting concepts for chunk 2/42...
# Extracting concepts for chunk 3/42...
# Extracting concepts for chunk 4/42...
# Extracting concepts for chunk 5/42...
# Extracting concepts for chunk 6/42...
# Extracting concepts for chunk 7/42...
# Extracting concepts for chunk 8/42...
# Extracting concepts for chunk 9/42...
# Extracting concepts for chunk 10/42...
# Extracting concepts for chunk 11/42...
# Extracting concepts for chunk 12/42...
# Extracting concepts for chunk 13/42...
# Extracting concepts for chunk 14/42...
# Extracting concepts for chunk 15/42...
# Extracting concepts for chunk 16/42...
# Extracting concepts for chunk 17/42...
# Extracting concepts for chunk 18/42...
# Extracting concepts for chunk 19/42...
# Extracting concepts for chunk 20/42...
# Extracting concepts for chunk 21/42...
# Extracting concepts for chunk 22/42...
# Extracting concepts for chunk 23/42...
# Extracting concepts for chunk 24/42...
# Extracting concepts for chunk 25/42...
# Extracting concepts for chunk 26/42...
# Extracting concepts for chunk 27/42...
# Extracting concepts for chunk 28/42...
# Extracting concepts for chunk 29/42...
# Extracting concepts for chunk 30/42...
# Extracting concepts for chunk 31/42...
# Extracting concepts for chunk 32/42...
# Extracting concepts for chunk 33/42...
# Extracting concepts for chunk 34/42...
# Extracting concepts for chunk 35/42...
# Extracting concepts for chunk 36/42...
# Extracting concepts for chunk 37/42...
# Extracting concepts for chunk 38/42...
# Extracting concepts for chunk 39/42...
# Extracting concepts for chunk 40/42...
# Extracting concepts for chunk 41/42...
# Extracting concepts for chunk 42/42...
# Creating edges between nodes...
# {'Computing Power', 'Data Availability', 'Symbolic Methods', 'Reasoning', 'Artificial Intelligence'}
# ===intersec between 1 and 2===
# {'Artificial Intelligence'}
# ===intersec between 1 and 3===
# {'Artificial Intelligence'}
# ===intersec between 1 and 4===
# set()
# ===intersec between 1 and 5===
# set()
# ===intersec between 1 and 6===
# set()
# ===intersec between 1 and 7===
# {'Artificial Intelligence'}
# ===intersec between 1 and 8===
# set()
# ===intersec between 1 and 9===
# set()
# ===intersec between 1 and 10===
# set()
# ===intersec between 1 and 11===
# set()
# ===intersec between 1 and 12===
# set()
# ===intersec between 1 and 13===
# set()
# ===intersec between 1 and 14===
# set()
# ===intersec between 1 and 15===
# set()
# ===intersec between 1 and 16===
# set()
# ===intersec between 1 and 17===
# set()
# ===intersec between 1 and 18===
# set()
# ===intersec between 1 and 19===
# set()
# ===intersec between 1 and 20===
# set()
# ===intersec between 1 and 21===
# set()
# ===intersec between 1 and 22===
# set()
# ===intersec between 1 and 23===
# set()
# ===intersec between 1 and 24===
# set()
# ===intersec between 1 and 25===
# set()
# ===intersec between 1 and 26===
# set()
# ===intersec between 1 and 27===
# set()
# ===intersec between 1 and 28===
# set()
# ===intersec between 1 and 29===
# set()
# ===intersec between 1 and 30===
# set()
# ===intersec between 1 and 31===
# set()
# ===intersec between 1 and 32===
# set()
# ===intersec between 1 and 33===
# set()
# ===intersec between 1 and 34===
# set()
# ===intersec between 1 and 35===
# {'Artificial Intelligence'}
# ===intersec between 1 and 36===
# set()
# ===intersec between 1 and 37===
# set()
# ===intersec between 1 and 38===
# set()
# ===intersec between 1 and 39===
# set()
# ===intersec between 1 and 40===
# set()
# ===intersec between 1 and 41===
# set()
# ===intersec between 1 and 42===
# set()
# {'Machine Learning', 'Expert Systems', 'Deep Learning', 'Neural Networks', 'Artificial Intelligence'}
# ===intersec between 2 and 3===
# {'Artificial Intelligence', 'Machine Learning'}
# ===intersec between 2 and 4===
# {'Deep Learning'}
# ===intersec between 2 and 5===
# {'Deep Learning'}
# ===intersec between 2 and 6===
# {'Machine Learning'}
# ===intersec between 2 and 7===
# {'Artificial Intelligence', 'Machine Learning'}
# ===intersec between 2 and 8===
# set()
# ===intersec between 2 and 9===
# set()
# ===intersec between 2 and 10===
# set()
# ===intersec between 2 and 11===
# set()
# ===intersec between 2 and 12===
# set()
# ===intersec between 2 and 13===
# set()
# ===intersec between 2 and 14===
# set()
# ===intersec between 2 and 15===
# set()
# ===intersec between 2 and 16===
# set()
# ===intersec between 2 and 17===
# {'Machine Learning'}
# ===intersec between 2 and 18===
# set()
# ===intersec between 2 and 19===
# set()
# ===intersec between 2 and 20===
# set()
# ===intersec between 2 and 21===
# set()
# ===intersec between 2 and 22===
# set()
# ===intersec between 2 and 23===
# set()
# ===intersec between 2 and 24===
# set()
# ===intersec between 2 and 25===
# set()
# ===intersec between 2 and 26===
# set()
# ===intersec between 2 and 27===
# set()
# ===intersec between 2 and 28===
# set()
# ===intersec between 2 and 29===
# set()
# ===intersec between 2 and 30===
# {'Deep Learning'}
# ===intersec between 2 and 31===
# set()
# ===intersec between 2 and 32===
# set()
# ===intersec between 2 and 33===
# set()
# ===intersec between 2 and 34===
# set()
# ===intersec between 2 and 35===
# {'Artificial Intelligence'}
# ===intersec between 2 and 36===
# set()
# ===intersec between 2 and 37===
# set()
# ===intersec between 2 and 38===
# set()
# ===intersec between 2 and 39===
# set()
# ===intersec between 2 and 40===
# set()
# ===intersec between 2 and 41===
# set()
# ===intersec between 2 and 42===
# set()
# {'Machine Learning', 'Unsupervised Learning', 'Bias', 'Artificial Intelligence', 'Supervised Learning'}
# ===intersec between 3 and 4===
# {'Unsupervised Learning'}
# ===intersec between 3 and 5===
# set()
# ===intersec between 3 and 6===
# {'Machine Learning'}
# ===intersec between 3 and 7===
# {'Artificial Intelligence', 'Machine Learning'}
# ===intersec between 3 and 8===
# set()
# ===intersec between 3 and 9===
# {'Bias'}
# ===intersec between 3 and 10===
# set()
# ===intersec between 3 and 11===
# set()
# ===intersec between 3 and 12===
# set()
# ===intersec between 3 and 13===
# {'Bias'}
# ===intersec between 3 and 14===
# set()
# ===intersec between 3 and 15===
# set()
# ===intersec between 3 and 16===
# ...
# ===intersec between 19 and 28===
# {'AI'}
# ===intersec between 19 and 29===
# {'AI'}
# ===intersec between 19 and 30===
# {'AI'}
# ===intersec between 19 and 31===
# {'AI'}
# ===intersec between 19 and 32===
# set()
# ===intersec between 19 and 33===
# set()
# ===intersec between 19 and 34===
# {'AI'}
# ===intersec between 19 and 35===
# {'AI'}
# ===intersec between 19 and 36===
# set()
# ===intersec between 19 and 37===
# {'AI'}
# ===intersec between 19 and 38===
# set()
# ===intersec between 19 and 39===
# set()
# ===intersec between 19 and 40===
# {'AI'}
# ===intersec between 19 and 41===
# set()
# ===intersec between 19 and 42===
# {'Reskilling'}
# {'Ethics', 'Collaboration', 'Creativity', 'Job Roles', 'AI'}
# ===intersec between 20 and 21===
# set()
# ===intersec between 20 and 22===
# {'AI'}
# ===intersec between 20 and 23===
# {'AI'}
# ===intersec between 20 and 24===
# set()
# ===intersec between 20 and 25===
# {'AI'}
# ===intersec between 20 and 26===
# {'AI'}
# ===intersec between 20 and 27===
# set()
# ===intersec between 20 and 28===
# {'AI'}
# ===intersec between 20 and 29===
# {'AI'}
# ===intersec between 20 and 30===
# {'AI'}
# ===intersec between 20 and 31===
# {'AI'}
# ===intersec between 20 and 32===
# set()
# ===intersec between 20 and 33===
# set()
# ===intersec between 20 and 34===
# {'AI'}
# ===intersec between 20 and 35===
# {'AI'}
# ===intersec between 20 and 36===
# {'Ethics'}
# ===intersec between 20 and 37===
# {'AI', 'Ethics'}
# ===intersec between 20 and 38===
# set()
# ===intersec between 20 and 39===
# set()
# ===intersec between 20 and 40===
# {'AI', 'Ethics'}
# ===intersec between 20 and 41===
# {'Ethics'}
# ===intersec between 20 and 42===
# set()
# {'AI in Writing and Content Creation', 'AI Algorithms', 'AI-Generated Art', 'AI-Driven Innovation', 'AI in Music Composition'}
# ===intersec between 21 and 22===
# set()
# ===intersec between 21 and 23===
# set()
# ===intersec between 21 and 24===
# set()
# ===intersec between 21 and 25===
# set()
# ===intersec between 21 and 26===
# set()
# ===intersec between 21 and 27===
# set()
# ===intersec between 21 and 28===
# set()
# ===intersec between 21 and 29===
# set()
# ===intersec between 21 and 30===
# set()
# ===intersec between 21 and 31===
# set()
# ===intersec between 21 and 32===
# set()
# ===intersec between 21 and 33===
# set()
# ===intersec between 21 and 34===
# set()
# ===intersec between 21 and 35===
# set()
# ===intersec between 21 and 36===
# set()
# ===intersec between 21 and 37===
# set()
# ===intersec between 21 and 38===
# set()
# ===intersec between 21 and 39===
# set()
# ===intersec between 21 and 40===
# set()
# ===intersec between 21 and 41===
# set()
# ===intersec between 21 and 42===
# set()
# {'Virtual Tutors', 'Adaptive Assessments', 'Personalized Learning', 'AI-powered tools', 'AI'}
# ===intersec between 22 and 23===
# {'AI'}
# ===intersec between 22 and 24===
# set()
# ===intersec between 22 and 25===
# {'AI'}
# ===intersec between 22 and 26===
# {'AI'}
# ===intersec between 22 and 27===
# set()
# ===intersec between 22 and 28===
# {'AI'}
# ===intersec between 22 and 29===
# {'AI'}
# ===intersec between 22 and 30===
# {'AI'}
# ===intersec between 22 and 31===
# {'AI'}
# ===intersec between 22 and 32===
# set()
# ===intersec between 22 and 33===
# set()
# ===intersec between 22 and 34===
# {'AI'}
# ===intersec between 22 and 35===
# {'AI'}
# ===intersec between 22 and 36===
# set()
# ===intersec between 22 and 37===
# {'AI'}
# ===intersec between 22 and 38===
# set()
# ===intersec between 22 and 39===
# set()
# ===intersec between 22 and 40===
# {'AI'}
# ===intersec between 22 and 41===
# set()
# ===intersec between 22 and 42===
# set()
# {'Medical Diagnosis', 'Educational Data Mining', 'Education', 'Automated Grading', 'AI'}
# ===intersec between 23 and 24===
# set()
# ===intersec between 23 and 25===
# {'AI'}
# ===intersec between 23 and 26===
# {'AI'}
# ===intersec between 23 and 27===
# set()
# ===intersec between 23 and 28===
# {'AI'}
# ===intersec between 23 and 29===
# {'AI'}
# ===intersec between 23 and 30===
# {'AI'}
# ===intersec between 23 and 31===
# {'AI'}
# ===intersec between 23 and 32===
# set()
# ===intersec between 23 and 33===
# set()
# ===intersec between 23 and 34===
# {'AI'}
# ===intersec between 23 and 35===
# {'AI'}
# ===intersec between 23 and 36===
# set()
# ===intersec between 23 and 37===
# {'AI'}
# ===intersec between 23 and 38===
# set()
# ===intersec between 23 and 39===
# set()
# ===intersec between 23 and 40===
# {'AI'}
# ===intersec between 23 and 41===
# set()
# ===intersec between 23 and 42===
# set()
# {'Drug Discovery', 'Artificial Intelligence (AI)', 'Robotic Surgery', 'Personalized Medicine', 'Medical Imaging'}
# ===intersec between 24 and 25===
# set()
# ===intersec between 24 and 26===
# set()
# ===intersec between 24 and 27===
# set()
# ===intersec between 24 and 28===
# set()
# ===intersec between 24 and 29===
# set()
# ===intersec between 24 and 30===
# set()
# ===intersec between 24 and 31===
# set()
# ===intersec between 24 and 32===
# {'Artificial Intelligence (AI)'}
# ===intersec between 24 and 33===
# set()
# ===intersec between 24 and 34===
# set()
# ===intersec between 24 and 35===
# set()
# ===intersec between 24 and 36===
# set()
# ===intersec between 24 and 37===
# set()
# ===intersec between 24 and 38===
# set()
# ===intersec between 24 and 39===
# set()
# ===intersec between 24 and 40===
# set()
# ===intersec between 24 and 41===
# set()
# ===intersec between 24 and 42===
# {'Artificial Intelligence (AI)'}
# {'Anomaly Detection', 'Cybersecurity', 'Fraud Detection', 'AI', 'Healthcare Administration'}
# ===intersec between 25 and 26===
# {'Fraud Detection', 'AI'}
# ===intersec between 25 and 27===
# set()
# ===intersec between 25 and 28===
# {'AI'}
# ===intersec between 25 and 29===
# {'AI'}
# ===intersec between 25 and 30===
# {'AI'}
# ===intersec between 25 and 31===
# {'AI'}
# ===intersec between 25 and 32===
# set()
# ===intersec between 25 and 33===
# set()
# ===intersec between 25 and 34===
# {'AI'}
# ===intersec between 25 and 35===
# {'AI'}
# ===intersec between 25 and 36===
# set()
# ===intersec between 25 and 37===
# {'AI'}
# ===intersec between 25 and 38===
# set()
# ===intersec between 25 and 39===
# set()
# ===intersec between 25 and 40===
# {'AI'}
# ===intersec between 25 and 41===
# set()
# ===intersec between 25 and 42===
# set()
# {'Cyberattacks', 'Fraud Detection', 'Vulnerability Management', 'Incident Response', 'AI'}
# ===intersec between 26 and 27===
# set()
# ===intersec between 26 and 28===
# {'AI'}
# ===intersec between 26 and 29===
# {'AI'}
# ===intersec between 26 and 30===
# {'AI'}
# ===intersec between 26 and 31===
# {'AI'}
# ===intersec between 26 and 32===
# set()
# ===intersec between 26 and 33===
# set()
# ===intersec between 26 and 34===
# {'AI'}
# ===intersec between 26 and 35===
# {'AI'}
# ===intersec between 26 and 36===
# set()
# ===intersec between 26 and 37===
# {'AI'}
# ===intersec between 26 and 38===
# set()
# ===intersec between 26 and 39===
# set()
# ===intersec between 26 and 40===
# {'AI'}
# ===intersec between 26 and 41===
# set()
# ===intersec between 26 and 42===
# set()
# {'Ethical Considerations', 'Poverty', 'Healthcare Disparities', 'Climate Change', 'AI for Social Good'}
# ===intersec between 27 and 28===
# set()
# ===intersec between 27 and 29===
# set()
# ===intersec between 27 and 30===
# set()
# ===intersec between 27 and 31===
# set()
# ===intersec between 27 and 32===
# set()
# ===intersec between 27 and 33===
# set()
# ===intersec between 27 and 34===
# set()
# ===intersec between 27 and 35===
# set()
# ===intersec between 27 and 36===
# set()
# ===intersec between 27 and 37===
# set()
# ===intersec between 27 and 38===
# set()
# ===intersec between 27 and 39===
# set()
# ===intersec between 27 and 40===
# set()
# ===intersec between 27 and 41===
# set()
# ===intersec between 27 and 42===
# set()
# {'Trust', 'Transparency', 'Urban Planning', 'Global Collaboration', 'AI'}
# ===intersec between 28 and 29===
# {'AI'}
# ===intersec between 28 and 30===
# {'AI'}
# ===intersec between 28 and 31===
# {'AI'}
# ===intersec between 28 and 32===
# set()
# ===intersec between 28 and 33===
# set()
# ===intersec between 28 and 34===
# {'AI'}
# ===intersec between 28 and 35===
# {'AI'}
# ===intersec between 28 and 36===
# {'Transparency'}
# ===intersec between 28 and 37===
# {'Transparency', 'AI'}
# ===intersec between 28 and 38===
# {'Transparency'}
# ===intersec between 28 and 39===
# {'Transparency'}
# ===intersec between 28 and 40===
# {'AI', 'Trust'}
# ===intersec between 28 and 41===
# {'Global Collaboration'}
# ===intersec between 28 and 42===
# set()
# {'Energy Management', 'Smart Transportation', 'Public Safety and Security', 'Environmental Monitoring', 'AI'}
# ===intersec between 29 and 30===
# {'Environmental Monitoring', 'AI'}
# ===intersec between 29 and 31===
# {'AI'}
# ===intersec between 29 and 32===
# set()
# ===intersec between 29 and 33===
# set()
# ===intersec between 29 and 34===
# {'Environmental Monitoring', 'AI'}
# ===intersec between 29 and 35===
# {'AI'}
# ===intersec between 29 and 36===
# set()
# ===intersec between 29 and 37===
# {'AI'}
# ===intersec between 29 and 38===
# set()
# ===intersec between 29 and 39===
# set()
# ===intersec between 29 and 40===
# {'AI'}
# ===intersec between 29 and 41===
# set()
# ===intersec between 29 and 42===
# set()
# {'Explainable AI (XAI)', 'Deep Learning', 'Neuroscience', 'Environmental Monitoring', 'AI'}
# ===intersec between 30 and 31===
# {'AI', 'Neuroscience'}
# ===intersec between 30 and 32===
# set()
# ===intersec between 30 and 33===
# set()
# ===intersec between 30 and 34===
# {'Environmental Monitoring', 'AI'}
# ===intersec between 30 and 35===
# {'AI'}
# ===intersec between 30 and 36===
# set()
# ===intersec between 30 and 37===
# {'AI'}
# ===intersec between 30 and 38===
# {'Explainable AI (XAI)'}
# ===intersec between 30 and 39===
# set()
# ===intersec between 30 and 40===
# {'AI'}
# ===intersec between 30 and 41===
# set()
# ===intersec between 30 and 42===
# set()
# {'Human-Centered AI', 'Generative AI', 'Neuroscience', 'Accountability', 'AI'}
# ===intersec between 31 and 32===
# set()
# ===intersec between 31 and 33===
# set()
# ===intersec between 31 and 34===
# {'AI'}
# ===intersec between 31 and 35===
# {'AI'}
# ===intersec between 31 and 36===
# set()
# ===intersec between 31 and 37===
# {'AI'}
# ===intersec between 31 and 38===
# {'Accountability'}
# ===intersec between 31 and 39===
# set()
# ===intersec between 31 and 40===
# {'AI'}
# ===intersec between 31 and 41===
# set()
# ===intersec between 31 and 42===
# set()
# {'Transformers', 'Generative Adversarial Networks (GANs)', 'Artificial Intelligence (AI)', 'AI-driven creativity', 'Collaborative AI'}
# ===intersec between 32 and 33===
# set()
# ===intersec between 32 and 34===
# set()
# ===intersec between 32 and 35===
# set()
# ===intersec between 32 and 36===
# set()
# ===intersec between 32 and 37===
# set()
# ===intersec between 32 and 38===
# set()
# ===intersec between 32 and 39===
# set()
# ===intersec between 32 and 40===
# set()
# ===intersec between 32 and 41===
# set()
# ===intersec between 32 and 42===
# {'Artificial Intelligence (AI)'}
# {'AI in Visual Arts and Design', 'Climate Change Mitigation', 'Precision Agriculture', 'AI in Interactive Media', 'Audio Mixing and Mastering'}
# ===intersec between 33 and 34===
# {'Precision Agriculture'}
# ===intersec between 33 and 35===
# set()
# ===intersec between 33 and 36===
# set()
# ===intersec between 33 and 37===
# set()
# ===intersec between 33 and 38===
# set()
# ===intersec between 33 and 39===
# set()
# ===intersec between 33 and 40===
# set()
# ===intersec between 33 and 41===
# set()
# ===intersec between 33 and 42===
# set()
# {'Wildlife Conservation', 'Precision Agriculture', 'Environmental Monitoring', 'Carbon Capture and Storage', 'AI'}
# ===intersec between 34 and 35===
# {'AI'}
# ===intersec between 34 and 36===
# set()
# ===intersec between 34 and 37===
# {'AI'}
# ===intersec between 34 and 38===
# set()
# ===intersec between 34 and 39===
# set()
# ===intersec between 34 and 40===
# {'AI'}
# ===intersec between 34 and 41===
# set()
# ===intersec between 34 and 42===
# set()
# {'Government Policy', 'Disaster Response', 'Regulation', 'Artificial Intelligence', 'AI'}
# ===intersec between 35 and 36===
# set()
# ===intersec between 35 and 37===
# {'AI'}
# ===intersec between 35 and 38===
# set()
# ===intersec between 35 and 39===
# set()
# ===intersec between 35 and 40===
# {'AI'}
# ===intersec between 35 and 41===
# set()
# ===intersec between 35 and 42===
# set()
# {'International Cooperation', 'Transparency', 'Ethics', 'Bias', 'Public Engagement'}
# ===intersec between 36 and 37===
# {'Transparency', 'Ethics', 'Bias'}
# ===intersec between 36 and 38===
# {'Transparency'}
# ===intersec between 36 and 39===
# {'Transparency'}
# ===intersec between 36 and 40===
# {'Ethics', 'Public Engagement'}
# ===intersec between 36 and 41===
# {'Ethics'}
# ===intersec between 36 and 42===
# set()
# {'Explainability', 'Transparency', 'Ethics', 'Bias', 'AI'}
# ===intersec between 37 and 38===
# {'Explainability', 'Transparency'}
# ===intersec between 37 and 39===
# {'Transparency'}
# ===intersec between 37 and 40===
# {'AI', 'Ethics'}
# ===intersec between 37 and 41===
# {'Ethics'}
# ===intersec between 37 and 42===
# set()
# {'Explainable AI (XAI)', 'Explainability', 'Transparency', 'Privacy', 'Accountability'}
# ===intersec between 38 and 39===
# {'Transparency'}
# ===intersec between 38 and 40===
# set()
# ===intersec between 38 and 41===
# set()
# ===intersec between 38 and 42===
# set()
# {'Reliability', 'Transparency', 'Ethical Design', 'User Control', 'Robustness'}
# ===intersec between 39 and 40===
# set()
# ===intersec between 39 and 41===
# set()
# ===intersec between 39 and 42===
# set()
# {'Trust', 'Ethics', 'Research', 'Public Engagement', 'AI'}
# ===intersec between 40 and 41===
# {'Ethics'}
# ===intersec between 40 and 42===
# set()
# {'Education and Workforce Development', 'Human-Centered Approach', 'Ethics', 'Responsible AI', 'Global Collaboration'}
# ===intersec between 41 and 42===
# {'Human-Centered Approach'}
# {'Artificial Intelligence (AI)', 'Human-Centered Approach', 'Lifelong Learning', 'Reskilling', 'Upskilling'}
# Knowledge graph built with 42 nodes and 45 edges
#
#
# === Evaluating Query 1/1 ===
# Query: How do transformers handle sequential data compared to RNNs?
# Traversing graph for query: How do transformers handle sequential data compared to RNNs?
# Starting traversal from 5 nodes
# Graph traversal found 6 relevant chunks
#
# Response: Transformers and Recurrent Neural Networks (RNNs) are both used to process sequential data, but they differ in their approach.
#
# RNNs, as mentioned in the provided context, are designed to process sequential data, such as text and time series, and have feedback connections that allow information to persist over time. This makes them suitable for tasks like language translation, speech recognition, and sentiment analysis.
#
# Transformers, on the other hand, are a type of neural network architecture that was introduced in the context of natural language processing. They are particularly effective for processing sequential data, but they do not rely on the same feedback connections as RNNs. Instead, transformers use self-attention mechanisms to weigh the importance of different parts of the input sequence relative to each other, allowing them to capture long-range dependencies in the data.
#
# In terms of handling sequential data, transformers are generally more efficient and scalable than RNNs, especially for longer sequences. This is because transformers do not require the same level of recurrent connections, which can be computationally expensive and prone to vanishing gradients. However, transformers can be more difficult to train and require more computational resources than RNNs.
#
# It's worth noting that transformers are not a replacement for RNNs, but rather a complementary approach that can be used in conjunction with RNNs or other architectures to improve performance on sequential data tasks.
#
# Comparison: The AI-generated response matches the reference answer in terms of correctness, completeness, and relevance to the query. Both responses accurately describe the key differences between transformers and RNNs in handling sequential data, including the use of self-attention mechanisms in transformers and the limitations of RNNs with long sequences. However, the AI response provides more details about the computational efficiency and scalability of transformers compared to RNNs, which is not explicitly mentioned in the reference answer. Overall, the AI response is a good summary of the key points, but could be improved by being more concise and directly comparing the two architectures.
#
#
# === EVALUATION SUMMARY ===
# Graph nodes: 42
# Graph edges: 45
#
# Query 1: How do transformers handle sequential data compared to RNNs?
# Path length: 6
# Chunks used: 6
